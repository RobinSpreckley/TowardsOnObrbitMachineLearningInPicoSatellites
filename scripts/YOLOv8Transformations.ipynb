# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#
# <br>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov8"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLOv8 and understand its features and capabilities.
#
# The YOLOv8 models are designed to be fast, accurate, and easy to use, making them an excellent choice for a wide range of object detection and image segmentation tasks. They can be trained on large datasets and are capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# Whether you are a seasoned machine learning practitioner or new to the field, we hope that the resources in this notebook will help you get the most out of YOLOv8. Please feel free to browse the <a href="https://docs.ultralytics.com/">YOLOv8 Docs</a> and reach out to us with any questions or feedback.
#
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/225.8 GB disk)

# %%
# %pip install git+https://github.com/motokimura/ultralytics.git@fix/tflite_integer_quant
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/motokimura/ultralytics.git@fix/tflite_integer_quant
#   Cloning https://github.com/motokimura/ultralytics.git (to revision fix/tflite_integer_quant) to /tmp/pip-req-build-m9qdq3cs
#   Running command git clone --filter=blob:none --quiet https://github.com/motokimura/ultralytics.git /tmp/pip-req-build-m9qdq3cs
#   Running command git checkout -b fix/tflite_integer_quant --track origin/fix/tflite_integer_quant
#   Switched to a new branch 'fix/tflite_integer_quant'
#   Branch 'fix/tflite_integer_quant' set up to track remote branch 'fix/tflite_integer_quant' from 'origin'.
#   Resolved https://github.com/motokimura/ultralytics.git to commit 6857bf7c4526ac54e9649bc1bcda98636b82a096
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (3.7.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (1.22.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (8.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (2.0.0+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (0.15.1+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.66) (5.9.4)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting sentry_sdk
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.66) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.4->ultralytics==8.0.66) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.66) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.66) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.66) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.66) (1.26.15)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (3.10.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.66) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.66) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.66) (3.25.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics==8.0.66) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.66) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.66) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7.0->ultralytics==8.0.66) (1.3.0)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (setup.py) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.0.66-py3-none-any.whl size=507281 sha256=2712fbb403e52e9deffad9dd058bba98fbf9d4a9b83a5db7dfaa1274167e10d6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kmux8nzm/wheels/a7/a1/91/566e40085fbb82ad793e2e45f5a303676a9481d826ab9477b6
# Successfully built ultralytics
# Installing collected packages: sentry_sdk, thop, ultralytics
# Successfully installed sentry_sdk-1.19.1 thop-0.1.1.post2209072238 ultralytics-8.0.66

# %%
# !git clone https://github.com/motokimura/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 4996, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 4996 (delta 15), reused 31 (delta 13), pack-reused 4933
# Receiving objects: 100% (4996/4996), 2.68 MiB | 4.86 MiB/s, done.
# Resolving deltas: 100% (3495/3495), done.

# %%
# %cd ultralytics
# Out:
# /content/ultralytics

# %%
# !git branch --all
# Out:
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/fix/tflite_integer_quant
#   remotes/origin/main

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) in the YOLOv8 [Docs](https://docs.ultralytics.com).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 266MB/s]
# Ultralytics YOLOv8.0.24 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to zidane.jpg...
# 100% 165k/165k [00:00<00:00, 87.4MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 13.3ms
# Speed: 0.5ms preprocess, 13.3ms inference, 43.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. The latest YOLOv8 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=diorallyolov8n_full_integer_quant.tflite data=DIORyolov8.yaml imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'task=segment' or 'task=classify'.
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# 2023-04-02 13:58:45.656449: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading diorallyolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/valid/labels.cache... 5863 images, 0 backgrounds, 0 corrupt: 100% 5863/5863 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5863/5863 [37:55<00:00,  2.58it/s]
#                    all       5863      35439          0          0          0          0
# Speed: 11.7ms preprocess, 342.7ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val5

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLOv8 on [Detection](https://docs.ultralytics.com/tasks/detection/), [Segmentation](https://docs.ultralytics.com/tasks/segmentation/) and [Classification](https://docs.ultralytics.com/tasks/classification/) datasets.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Mar 26 20:05:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    25W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Train YOLOv8n on COCO128 for 3 epochs
# !yolo train model=yolov8n.pt data=DIORv8.yaml epochs=1 imgsz=800
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=DIORv8.yaml, epochs=1, patience=50, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train3
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 16.1MB/s]
# Overriding model.yaml nc=80 with nc=20
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    755212  ultralytics.nn.modules.Detect                [20, [64, 128, 256]]
# Model summary: 225 layers, 3014748 parameters, 3014732 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# 2023-04-02 13:24:34.747028: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-02 13:24:36.118274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/cfg/__init__.py", line 326, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/model.py", line 330, in train
#     self.trainer.train()
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py", line 191, in train
#     self._do_train(world_size)
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py", line 266, in _do_train
#     self._setup_train(world_size)
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py", line 249, in _setup_train
#     self.train_loader = self.get_dataloader(self.trainset, batch_size=batch_size, rank=RANK, mode='train')
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/v8/detect/train.py", line 43, in get_dataloader
#     build_dataloader(self.args, batch_size, img_path=dataset_path, stride=gs, rank=rank, mode=mode,
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/data/build.py", line 71, in build_dataloader
#     dataset = YOLODataset(
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/data/dataset.py", line 66, in __init__
#     super().__init__(img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls,
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/data/base.py", line 47, in __init__
#     self.im_files = self.get_img_files(self.img_path)
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/data/base.py", line 78, in get_img_files
#     f += glob.glob(str(p / '**' / '*.*'), recursive=True)
#   File "/usr/lib/python3.9/glob.py", line 22, in glob
#     return list(iglob(pathname, recursive=recursive))
#   File "/usr/lib/python3.9/glob.py", line 75, in _iglob
#     for name in glob_in_dir(dirname, basename, dironly):
#   File "/usr/lib/python3.9/glob.py", line 83, in _glob1
#     names = _listdir(dirname, dironly)
#   File "/usr/lib/python3.9/glob.py", line 136, in _listdir
#     return list(it)
#   File "/usr/lib/python3.9/glob.py", line 124, in _iterdir
#     with os.scandir(dirname) as it:
# KeyboardInterrupt
# ^C

# %%
# !dir
# Out:
# diorallyolov8n.onnx	    diorallyolov8s.onnx		DIORv8.yaml  yolov8n.pt
# diorallyolov8n.pt	    diorallyolov8s.pt		drive
# diorallyolov8n_saved_model  diorallyolov8s_saved_model	runs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 4. Export
#
# Export a YOLOv8 model to any supported format with the `format` argument, i.e. `format=onnx`.
#
# - 💡 ProTip: Export to [ONNX](https://onnx.ai/) or [OpenVINO](https://docs.openvino.ai/latest/index.html) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://developer.nvidia.com/tensorrt) for up to 5x GPU speedup.
#
#
# | Format                                                                     | `format=`          | Model                     |
# |----------------------------------------------------------------------------|--------------------|---------------------------|
# | [PyTorch](https://pytorch.org/)                                            | -                  | `yolov8n.pt`              |
# | [TorchScript](https://pytorch.org/docs/stable/jit.html)                    | `torchscript`      | `yolov8n.torchscript`     |
# | [ONNX](https://onnx.ai/)                                                   | `onnx`             | `yolov8n.onnx`            |
# | [OpenVINO](https://docs.openvino.ai/latest/index.html)                     | `openvino`         | `yolov8n_openvino_model/` |
# | [TensorRT](https://developer.nvidia.com/tensorrt)                          | `engine`           | `yolov8n.engine`          |
# | [CoreML](https://github.com/apple/coremltools)                             | `coreml`           | `yolov8n.mlmodel`         |
# | [TensorFlow SavedModel](https://www.tensorflow.org/guide/saved_model)      | `saved_model`      | `yolov8n_saved_model/`    |
# | [TensorFlow GraphDef](https://www.tensorflow.org/api_docs/python/tf/Graph) | `pb`               | `yolov8n.pb`              |
# | [TensorFlow Lite](https://www.tensorflow.org/lite)                         | `tflite`           | `yolov8n.tflite`          |
# | [TensorFlow Edge TPU](https://coral.ai/docs/edgetpu/models-intro/)         | `edgetpu`          | `yolov8n_edgetpu.tflite`  |
# | [TensorFlow.js](https://www.tensorflow.org/js)                             | `tfjs`             | `yolov8n_web_model/`      |
# | [PaddlePaddle](https://github.com/PaddlePaddle)                            | `paddle`           | `yolov8n_paddle_model/`   |

# %%
# !yolo export model=diorallyolov8n.pt data=DIORyolov8.yaml format=edgetpu imgsz=350 #most recent 400 was to much
#!yolo val model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite data=DIORyolov8.yaml imgsz=416
# Out:
# 2023-04-05 12:30:43.389703: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 12:30:45.257656: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# WARNING ⚠️ imgsz=[350] must be multiple of max stride 32, updating to [352]
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorallyolov8n.pt with input shape (1, 3, 352, 352) BCHW and output shape(s) (1, 24, 2541) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 6.6s, saved as diorallyolov8n.onnx (11.6 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8n.onnx -o diorallyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-05 12:36:09.135130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 12:36:09.135494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 12:36:09.136097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 12:36:09.136215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 12:36:09.136618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 12:36:09.136705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 12:36:09.136909: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 12:36:09.137282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 12:36:09.137366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 12:36:09.137820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 12:36:09.137903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 12:36:09.138116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 12:36:09.138484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 12:36:09.138582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 12:36:09.139021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 12:36:09.139103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 12:36:09.139317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 12:36:09.139669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 12:36:09.139752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 12:36:09.140088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 12:36:09.140167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 12:36:09.140827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 12:36:09.140913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 12:36:09.141274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 12:36:09.141357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 12:36:09.141806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 12:36:09.141892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 12:36:09.142238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 12:36:09.142320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 12:36:09.142512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 12:36:09.142884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 12:36:09.142966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 12:36:09.143380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 12:36:09.143470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 12:36:09.143689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 12:36:09.144071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 12:36:09.144151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 12:36:09.144505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 12:36:09.144596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 12:36:09.145752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 12:36:09.145849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 12:36:09.222689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 12:36:09.222939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 12:36:09.223565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 12:36:09.223756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 12:36:09.224281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 12:36:09.224499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_35_stridedslice_end}}]]
# 2023-04-05 12:36:09.318394: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-04-05 12:36:09.400730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 12:36:09.401054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 12:36:09.401559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 12:36:09.401687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 12:36:09.402107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 12:36:09.402244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 12:36:09.402492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 12:36:09.402902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 12:36:09.403021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 12:36:09.403528: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 12:36:09.403655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 12:36:09.403903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 12:36:09.404315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 12:36:09.404425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 12:36:09.404917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 12:36:09.405029: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 12:36:09.405277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 12:36:09.405675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 12:36:09.405786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 12:36:09.406170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 12:36:09.406299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 12:36:09.406985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 12:36:09.407108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 12:36:09.407502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 12:36:09.407622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 12:36:09.408115: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 12:36:09.408240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 12:36:09.408624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 12:36:09.408733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 12:36:09.408965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 12:36:09.409405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 12:36:09.409514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 12:36:09.409890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 12:36:09.410001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 12:36:09.410253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 12:36:09.410686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 12:36:09.410795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 12:36:09.411164: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 12:36:09.411294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 12:36:09.412441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 12:36:09.425448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 12:36:09.426450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 12:36:09.426630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 12:36:09.427101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 12:36:09.427269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 12:36:09.427624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 12:36:09.427774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_end}}]]
# 2023-04-05 12:36:09.603062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 12:36:09.603389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 12:36:09.603863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 12:36:09.603985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 12:36:09.604426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 12:36:09.604546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 12:36:09.604793: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 12:36:09.605218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 12:36:09.605330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 12:36:09.605836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 12:36:09.605950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 12:36:09.606211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 12:36:09.606609: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 12:36:09.606716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 12:36:09.607227: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 12:36:09.607345: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 12:36:09.607595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 12:36:09.607976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 12:36:09.608093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 12:36:09.608511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 12:36:09.608627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 12:36:09.609332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 12:36:09.609445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 12:36:09.609826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 12:36:09.609935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# ...
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 12:36:10.350054: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 12:36:10.350134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 12:36:10.350501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 12:36:10.350585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 12:36:10.351217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 12:36:10.351304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 12:36:10.351648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 12:36:10.351730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 12:36:10.352156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 12:36:10.352254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 12:36:10.352601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 12:36:10.352682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 12:36:10.352871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 12:36:10.353259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 12:36:10.353342: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 12:36:10.353674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 12:36:10.353755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 12:36:10.353942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 12:36:10.354325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 12:36:10.354420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 12:36:10.354747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 12:36:10.354825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 12:36:10.355958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 12:36:10.356053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 12:36:10.439683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 12:36:10.439933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 12:36:10.440472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 12:36:10.440603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 12:36:10.440965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 12:36:10.441234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_end}}]]
# TensorFlow SavedModel: export success ✅ 323.1s, saved as diorallyolov8n_saved_model (38.7 MB)
# Edge TPU: WARNING ⚠️ Edge TPU known bug https://github.com/ultralytics/ultralytics/issues/1185
#
# Edge TPU: starting export with Edge TPU compiler 16.0.384591198...
# Edge TPU: running 'edgetpu_compiler -s -d -k 10 --out_dir diorallyolov8n_saved_model diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite'
# Edge TPU Compiler version 16.0.384591198
# Searching for valid delegate with step 10
# Try to compile segment with 257 ops
# Started a compilation timeout timer of 180 seconds.
#
# Model compiled successfully in 2979 ms.
#
# Input model: diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite
# Input size: 2.96MiB
# Output model: diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite
# Output size: 3.66MiB
# On-chip memory used for caching model parameters: 3.27MiB
# On-chip memory remaining for caching model parameters: 4.18MiB
# Off-chip memory used for streaming uncached model parameters: 0.00B
# Number of Edge TPU subgraphs: 1
# Total number of operations: 257
# Operation log: diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.log
#
# Model successfully compiled but not all operations are supported by the Edge TPU. A percentage of the model will instead run on the CPU, which is slower. If possible, consider updating your model to use only operations supported by the Edge TPU. For details, visit g.co/coral/model-reqs.
# Number of operations that will run on Edge TPU: 233
# Number of operations that will run on CPU: 24
#
# Operator                       Count      Status
#
# TRANSPOSE                      2          Mapped to Edge TPU
# TRANSPOSE                      3          Operation is otherwise supported, but not mapped due to some unspecified limitation
# RESHAPE                        1          More than one subgraph is not supported
# RESHAPE                        2          Mapped to Edge TPU
# RESHAPE                        2          Operation is otherwise supported, but not mapped due to some unspecified limitation
# MUL                            3          More than one subgraph is not supported
# MUL                            57         Mapped to Edge TPU
# SOFTMAX                        1          More than one subgraph is not supported
# CONCATENATION                  3          More than one subgraph is not supported
# CONCATENATION                  16         Mapped to Edge TPU
# RESIZE_NEAREST_NEIGHBOR        2          Mapped to Edge TPU
# LOGISTIC                       1          More than one subgraph is not supported
# LOGISTIC                       57         Mapped to Edge TPU
# CONV_2D                        63         Mapped to Edge TPU
# CONV_2D                        1          More than one subgraph is not supported
# QUANTIZE                       1          More than one subgraph is not supported
# QUANTIZE                       2          Mapped to Edge TPU
# STRIDED_SLICE                  2          More than one subgraph is not supported
# STRIDED_SLICE                  2          Operation is otherwise supported, but not mapped due to some unspecified limitation
# STRIDED_SLICE                  16         Mapped to Edge TPU
# MAX_POOL_2D                    3          Mapped to Edge TPU
# ADD                            2          More than one subgraph is not supported
# ADD                            6          Mapped to Edge TPU
# SUB                            2          More than one subgraph is not supported
# PAD                            7          Mapped to Edge TPU
# Compilation child process completed within timeout period.
# Compilation succeeded!
# Edge TPU: export success ✅ 3.5s, saved as diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite (3.7 MB)
#
# Export complete (327.2s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=352
# Validate:        yolo val task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=352 data=DIORyolov8.yaml
# Visualize:       https://netron.app

# %%
#!yolo export model=diorallyolov8n.pt data=DIORyolov8.yaml format=tflite int8

# %%
# !edgetpu_compiler -sad diorshipyolov8n_full_integer_quant.tflite

# %%
# !edgetpu_compiler -sad yolov5n-diorall-int8.tflite

# %%
# !yolo export model=diorallyolov8s.pt data=DIORyolov8.yaml format=tflite int8
# Out:
# 2023-04-04 16:35:40.640375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 11133324 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from diorallyolov8s.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 24, 13125) (21.5 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 7.9s, saved as diorallyolov8s.onnx (42.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8s.onnx -o diorallyolov8s_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8s_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-04 17:08:21.945078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# TensorFlow SavedModel: export success ✅ 1958.8s, saved as diorallyolov8s_saved_model (140.3 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.12.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as diorallyolov8s_saved_model/diorallyolov8s_int8.tflite (0.0 MB)
#
# Export complete (1960.7s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8s_saved_model/diorallyolov8s_int8.tflite imgsz=800
# Validate:        yolo val task=detect model=diorallyolov8s_saved_model/diorallyolov8s_int8.tflite imgsz=800 data=DIORyolov8.yaml
# Visualize:       https://netron.app

# %%
# !yolo export model=diorallyolov8n.pt data=DIORyolov8.yaml format=tflite int8
# Out:
# 2023-04-04 17:08:38.810064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorallyolov8n.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 24, 13125) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 3.2s, saved as diorallyolov8n.onnx (11.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8n.onnx -o diorallyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-04 17:24:49.916545: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# TensorFlow SavedModel: export success ✅ 969.8s, saved as diorallyolov8n_saved_model (39.5 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.12.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as diorallyolov8n_saved_model/diorallyolov8n_int8.tflite (0.0 MB)
#
# Export complete (970.8s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8n_saved_model/diorallyolov8n_int8.tflite imgsz=800
# Validate:        yolo val task=detect model=diorallyolov8n_saved_model/diorallyolov8n_int8.tflite imgsz=800 data=DIORyolov8.yaml
# Visualize:       https://netron.app

# %%
# !yolo export model=diorshipyolov8n.pt data=DIORship.yaml format=tflite int8
# Out:
# 2023-04-04 17:24:58.783000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorshipyolov8n.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 5, 13125) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 5.2s, saved as diorshipyolov8n.onnx (11.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorshipyolov8n.onnx -o diorshipyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorshipyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-04 17:41:00.277909: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# TensorFlow SavedModel: export success ✅ 958.8s, saved as diorshipyolov8n_saved_model (39.5 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.12.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as diorshipyolov8n_saved_model/diorshipyolov8n_int8.tflite (0.0 MB)
#
# Export complete (960.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorshipyolov8n_saved_model/diorshipyolov8n_int8.tflite imgsz=800
# Validate:        yolo val task=detect model=diorshipyolov8n_saved_model/diorshipyolov8n_int8.tflite imgsz=800 data=DIORship.yaml
# Visualize:       https://netron.app

# %%
# !yolo export model=diorshipyolov8s.pt data=DIORship.yaml format=tflite int8
# Out:
# 2023-04-04 17:41:07.482358: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from diorshipyolov8s.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 5, 13125) (21.5 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 8.3s, saved as diorshipyolov8s.onnx (42.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorshipyolov8s.onnx -o diorshipyolov8s_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorshipyolov8s_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-04 18:13:34.088403: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# TensorFlow SavedModel: export success ✅ 1943.2s, saved as diorshipyolov8s_saved_model (140.2 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.12.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as diorshipyolov8s_saved_model/diorshipyolov8s_int8.tflite (0.0 MB)
#
# Export complete (1946.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorshipyolov8s_saved_model/diorshipyolov8s_int8.tflite imgsz=800
# Validate:        yolo val task=detect model=diorshipyolov8s_saved_model/diorshipyolov8s_int8.tflite imgsz=800 data=DIORship.yaml
# Visualize:       https://netron.app

# %%
# !yolo export model=diorshipyolov8s.pt data=DIORyolov8.yaml format=edgetpu

# %%
# !yolo export model=diorshipyolov8n.pt data=DIORyolov8.yaml format=edgetpu

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.61
# Summary: Ultralytics YOLOv8
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: GPL-3.0
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: matplotlib, numpy, opencv-python, pandas, Pillow, psutil, PyYAML, requests, scipy, seaborn, sentry-sdk, thop, torch, torchvision, tqdm
# Required-by:

# %%
from ultralytics import YOLO

model = YOLO('diorallyolov8n.pt')
model.export(format='edgetpu')
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorallyolov8n.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 24, 13125) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: simplifying with onnxsim 0.4.19...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success ✅ 2.6s, saved as diorallyolov8n.onnx (11.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8n.onnx -o diorallyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# TensorFlow SavedModel: export success ✅ 974.2s, saved as diorallyolov8n_saved_model (39.5 MB)
# Edge TPU: WARNING ⚠️ Edge TPU known bug https://github.com/ultralytics/ultralytics/issues/1185
#
# Edge TPU: starting export with Edge TPU compiler 16.0.384591198...
# Edge TPU: running 'edgetpu_compiler -s -d -k 10 --out_dir diorallyolov8n_saved_model diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite'
# Edge TPU: export success ✅ 25.7s, saved as diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite (3.4 MB)
#
# Export complete (1000.7s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=800
# Validate:        yolo val task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=800 data=DIORyolov8.yaml
# Visualize:       https://netron.app
# 'diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite'

# %%
# !yolo export model=diorallyolov8n.pt data=DIORyolov8.yaml format=tflite int8 imgsz=256
# Out:
# 2023-04-05 16:06:52.266647: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 16:06:53.475394: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorallyolov8n.pt with input shape (1, 3, 256, 256) BCHW and output shape(s) (1, 24, 1344) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: simplifying with onnxsim 0.4.19...
# ONNX: export success ✅ 3.1s, saved as diorallyolov8n.onnx (11.6 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8n.onnx -o diorallyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2023-04-05 16:10:19.208642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 16:10:19.208947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 16:10:19.209561: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 16:10:19.209690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 16:10:19.210117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 16:10:19.210246: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 16:10:19.210492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 16:10:19.210909: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 16:10:19.211018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 16:10:19.211535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 16:10:19.211671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 16:10:19.211922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 16:10:19.212334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 16:10:19.212442: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 16:10:19.212940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 16:10:19.213049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 16:10:19.213309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 16:10:19.213706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 16:10:19.213813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 16:10:19.214215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 16:10:19.214321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 16:10:19.215022: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 16:10:19.215155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 16:10:19.215548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 16:10:19.215662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 16:10:19.216147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 16:10:19.216265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 16:10:19.216661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 16:10:19.216766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 16:10:19.216998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 16:10:19.217466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 16:10:19.217579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 16:10:19.217969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 16:10:19.218074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 16:10:19.218322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node model_tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 16:10:19.218766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 16:10:19.218871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 16:10:19.219266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 16:10:19.219370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node model_tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 16:10:19.220594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 16:10:19.220711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 16:10:19.233103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 16:10:19.233293: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 16:10:19.233745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 16:10:19.233895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 16:10:19.234277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 16:10:19.234376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'model_tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node model_tf_strided_slice_35_stridedslice_end}}]]
# 2023-04-05 16:10:19.311757: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-04-05 16:10:19.386544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 16:10:19.386800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 16:10:19.387242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 16:10:19.387334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 16:10:19.387694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 16:10:19.387777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 16:10:19.388007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 16:10:19.388395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 16:10:19.388480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 16:10:19.388910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 16:10:19.388995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 16:10:19.389221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 16:10:19.389560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 16:10:19.389644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 16:10:19.390069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 16:10:19.390166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 16:10:19.390380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 16:10:19.390717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 16:10:19.390800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 16:10:19.391143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 16:10:19.391242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 16:10:19.391867: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 16:10:19.391956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 16:10:19.392318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 16:10:19.392402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 16:10:19.392834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 16:10:19.392917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 16:10:19.393266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 16:10:19.393350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 16:10:19.393544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 16:10:19.393905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 16:10:19.393987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 16:10:19.394347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 16:10:19.394430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 16:10:19.394629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 16:10:19.395369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 16:10:19.395465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 16:10:19.395815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 16:10:19.395971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 16:10:19.397070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 16:10:19.433912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 16:10:19.434857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 16:10:19.435003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 16:10:19.435486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 16:10:19.435635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 16:10:19.435982: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 16:10:19.436130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_end}}]]
# 2023-04-05 16:10:19.603782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_pad_paddings}}]]
# 2023-04-05 16:10:19.604049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_1_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_1_pad_paddings}}]]
# 2023-04-05 16:10:19.604481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_ones_like_tensor}}]]
# 2023-04-05 16:10:19.604572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_3_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_3_stridedslice_end}}]]
# 2023-04-05 16:10:19.604948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_ones_like_tensor}}]]
# 2023-04-05 16:10:19.605033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_1_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_1_stridedslice_end}}]]
# 2023-04-05 16:10:19.605257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_2_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 16:10:19.605632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 16:10:19.605717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 16:10:19.606150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 16:10:19.606293: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 16:10:19.606520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 16:10:19.606873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 16:10:19.606958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 16:10:19.607433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 16:10:19.607520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 16:10:19.607727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 16:10:19.608059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 16:10:19.608139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 16:10:19.608494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 16:10:19.608576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 16:10:19.609225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 16:10:19.609314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 16:10:19.609651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 16:10:19.609733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# ...
# 	 [[{{node tf_compat_v1_pad_2_pad_paddings}}]]
# 2023-04-05 16:10:20.387747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_ones_like_tensor}}]]
# 2023-04-05 16:10:20.387878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_7_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_7_stridedslice_end}}]]
# 2023-04-05 16:10:20.388405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_ones_like_tensor}}]]
# 2023-04-05 16:10:20.388517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_5_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_5_stridedslice_end}}]]
# 2023-04-05 16:10:20.388761: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_3_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_3_pad_paddings}}]]
# 2023-04-05 16:10:20.389154: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_ones_like_tensor}}]]
# 2023-04-05 16:10:20.389276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_11_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_11_stridedslice_end}}]]
# 2023-04-05 16:10:20.389809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_ones_like_tensor}}]]
# 2023-04-05 16:10:20.389920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_9_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_9_stridedslice_end}}]]
# 2023-04-05 16:10:20.390162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_4_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_4_pad_paddings}}]]
# 2023-04-05 16:10:20.390570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_ones_like_tensor}}]]
# 2023-04-05 16:10:20.390677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_15_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_15_stridedslice_end}}]]
# 2023-04-05 16:10:20.391070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_ones_like_tensor}}]]
# 2023-04-05 16:10:20.391186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_13_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_13_stridedslice_end}}]]
# 2023-04-05 16:10:20.391906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_ones_like_tensor}}]]
# 2023-04-05 16:10:20.392026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_19_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_19_stridedslice_end}}]]
# 2023-04-05 16:10:20.392427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_ones_like_tensor}}]]
# 2023-04-05 16:10:20.392535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_17_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_17_stridedslice_end}}]]
# 2023-04-05 16:10:20.393033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_ones_like_tensor}}]]
# 2023-04-05 16:10:20.393141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_23_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_23_stridedslice_end}}]]
# 2023-04-05 16:10:20.393542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_ones_like_tensor}}]]
# 2023-04-05 16:10:20.393652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_21_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_21_stridedslice_end}}]]
# 2023-04-05 16:10:20.393886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_5_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_5_pad_paddings}}]]
# 2023-04-05 16:10:20.394324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_ones_like_tensor}}]]
# 2023-04-05 16:10:20.394434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_27_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_27_stridedslice_end}}]]
# 2023-04-05 16:10:20.394817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_ones_like_tensor}}]]
# 2023-04-05 16:10:20.394923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_25_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_25_stridedslice_end}}]]
# 2023-04-05 16:10:20.395216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_compat_v1_pad_6_pad_paddings' with dtype int32 and shape [4,2]
# 	 [[{{node tf_compat_v1_pad_6_pad_paddings}}]]
# 2023-04-05 16:10:20.395674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_ones_like_tensor}}]]
# 2023-04-05 16:10:20.395782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_31_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_31_stridedslice_end}}]]
# 2023-04-05 16:10:20.396164: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_ones_like_tensor' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_ones_like_tensor}}]]
# 2023-04-05 16:10:20.396286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_29_stridedslice_end' with dtype int64 and shape [4]
# 	 [[{{node tf_strided_slice_29_stridedslice_end}}]]
# 2023-04-05 16:10:20.397514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_begin}}]]
# 2023-04-05 16:10:20.397632: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_33_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_33_stridedslice_end}}]]
# 2023-04-05 16:10:20.475847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_ones_like_tensor}}]]
# 2023-04-05 16:10:20.476050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_39_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_39_stridedslice_end}}]]
# 2023-04-05 16:10:20.476571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_ones_like_tensor' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_ones_like_tensor}}]]
# 2023-04-05 16:10:20.476728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_37_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_37_stridedslice_end}}]]
# 2023-04-05 16:10:20.477140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_begin' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_begin}}]]
# 2023-04-05 16:10:20.477304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'tf_strided_slice_35_stridedslice_end' with dtype int64 and shape [3]
# 	 [[{{node tf_strided_slice_35_stridedslice_end}}]]
# TensorFlow SavedModel: export success ✅ 205.8s, saved as diorallyolov8n_saved_model (38.6 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.12.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as diorallyolov8n_saved_model/diorallyolov8n_int8.tflite (0.0 MB)
#
# Export complete (206.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8n_saved_model/diorallyolov8n_int8.tflite imgsz=256
# Validate:        yolo val task=detect model=diorallyolov8n_saved_model/diorallyolov8n_int8.tflite imgsz=256 data=DIORyolov8.yaml
# Visualize:       https://netron.app

# %%
# !yolo export model=diorallyolov8n.pt data=DIORyolov8.yaml format=tflite int8 imgsz=256

# %%
# !yolo val model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite data=DIORyolov8.yaml imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'task=segment' or 'task=classify'.
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# 2023-04-02 15:19:37.360848: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/valid/labels... 5863 images, 0 backgrounds, 0 corrupt: 100% 5863/5863 [20:22<00:00,  4.80it/s]
# val: New cache created: /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/valid/labels.cache
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5863/5863 [37:06<00:00,  2.63it/s]
#                    all       5863      35439          0          0          0          0
# Speed: 6.7ms preprocess, 341.5ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val14

# %%
from ultralytics import YOLO

model = YOLO('diorallyolov8n.pt')
model.val()
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/valid/labels.cache... 5863 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5863/5863 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   1%|          | 2/367 [00:24<1:13:05, 12.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-818a296e771b> in <cell line: 4>()
#       2
#       3 model = YOLO('diorallyolov8n.pt')
# ----> 4 model.val()
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/model.py in val(self, data, **kwargs)
#     264
#     265         validator = TASK_MAP[self.task][2](args=args)
# --> 266         validator(model=self.model)
#     267         self.metrics = validator.metrics
#     268
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/validator.py in __call__(self, trainer, model)
#     157             # inference
#     158             with dt[1]:
# --> 159                 preds = model(batch['img'])
#     160
#     161             # loss
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize)
#     305
#     306         if self.pt or self.nn_module:  # PyTorch
# --> 307             y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     308         elif self.jit:  # TorchScript
#     309             y = self.model(im)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/nn/tasks.py in forward(self, x, augment, profile, visualize)
#     201         if augment:
#     202             return self._forward_augment(x)  # augmented inference, None
# --> 203         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     204
#     205     def _forward_augment(self, x):
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/nn/tasks.py in _forward_once(self, x, profile, visualize)
#      56             if profile:
#      57                 self._profile_one_layer(m, x, dt)
# ---> 58             x = m(x)  # run
#      59             y.append(x if m.i in self.save else None)  # save output
#      60             if visualize:
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/nn/modules.py in forward(self, x)
#     192         y = list(self.cv1(x).chunk(2, 1))
#     193         y.extend(m(y[-1]) for m in self.m)
# --> 194         return self.cv2(torch.cat(y, 1))
#     195
#     196     def forward_split(self, x):
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/nn/modules.py in forward_fuse(self, x)
#      35
#      36     def forward_fuse(self, x):
# ---> 37         return self.act(self.conv(x))
#      38
#      39
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %%
# !yolo val task=detect model=diorallyolov8n_full_integer_quant.tflite imgsz=800 data=DIORyolov8test.yaml#new stuff
# Out:
# 2023-04-05 16:52:50.321231: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 16:52:52.053360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorallyolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels... 11738 images, 5 backgrounds, 0 corrupt: 100% 11743/11743 [1:39:49<00:00,  1.96it/s]
# val: New cache created: /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [1:09:09<00:00,  2.83it/s]
#                    all      11743     124445      0.708      0.548      0.582      0.353
#              golffield      11743        575      0.734      0.642      0.625       0.36
# Expressway-toll-station      11743        688      0.785      0.493      0.534      0.366
#                vehicle      11743      26640      0.479      0.308       0.29       0.13
#           trainstation      11743        509      0.487      0.432      0.422      0.191
#                chimney      11743       1031      0.923      0.715      0.745      0.551
#            storagetank      11743      23361      0.592      0.502      0.522      0.266
#                   ship      11743      35186      0.611      0.728      0.635      0.291
#                 harbor      11743       3105      0.735      0.468       0.54      0.316
#               airplane      11743       8212      0.567      0.664      0.659      0.374
#       groundtrackfield      11743       1885      0.742       0.53      0.627       0.42
#            tenniscourt      11743       7343      0.718      0.794      0.814      0.549
#                    dam      11743        538      0.612      0.444      0.471      0.235
#        basketballcourt      11743       2146      0.859      0.826      0.851      0.599
# Expressway-Service-area      11743       1085      0.921      0.534      0.575      0.404
#                stadium      11743        672      0.773      0.332      0.519      0.344
#                airport      11743        666      0.769      0.523      0.628      0.367
#          baseballfield      11743       3434      0.906      0.636      0.739      0.535
#                 bridge      11743       2589      0.624      0.273      0.326      0.172
#               windmill      11743       2998      0.556      0.633      0.597      0.272
#               overpass      11743       1782      0.769      0.475      0.521       0.31
# Speed: 2.9ms preprocess, 305.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val3

# %%
# !yolo val task=detect model=diorallyolov8s_full_integer_quant.tflite imgsz=800 data=DIORyolov8test.yaml
# Out:
# 2023-04-05 19:42:26.881835: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 19:42:29.365819: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorallyolov8s_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 5 backgrounds, 0 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [2:56:49<00:00,  1.11it/s]
#                    all      11743     124445      0.732      0.558      0.605      0.364
#              golffield      11743        575      0.808      0.645      0.684      0.413
# Expressway-toll-station      11743        688        0.8      0.504      0.574      0.386
#                vehicle      11743      26640       0.46      0.338       0.31      0.133
#           trainstation      11743        509      0.497       0.45      0.401      0.191
#                chimney      11743       1031      0.956      0.717      0.777      0.571
#            storagetank      11743      23361      0.614       0.51       0.56      0.275
#                   ship      11743      35186      0.626      0.677      0.597      0.266
#                 harbor      11743       3105      0.691      0.459       0.51      0.291
#               airplane      11743       8212      0.649      0.696      0.728      0.404
#       groundtrackfield      11743       1885      0.686      0.606      0.675      0.458
#            tenniscourt      11743       7343      0.734      0.805      0.824      0.548
#                    dam      11743        538       0.64      0.468      0.474      0.243
#        basketballcourt      11743       2146      0.853      0.854      0.861      0.609
# Expressway-Service-area      11743       1085      0.975      0.508      0.594      0.409
#                stadium      11743        672      0.868      0.378       0.62      0.397
#                airport      11743        666      0.872       0.45       0.66      0.401
#          baseballfield      11743       3434      0.902      0.646      0.741      0.528
#                 bridge      11743       2589      0.652       0.31      0.371      0.187
#               windmill      11743       2998      0.625      0.642      0.624      0.286
#               overpass      11743       1782      0.724      0.492       0.52      0.293
# Speed: 5.2ms preprocess, 866.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val4

# %%
# !yolo val task=detect model=diorshipyolov8n_full_integer_quant.tflite imgsz=800 data=DIORshipyolov8test.yaml #new stuff
# Out:
# 2023-04-06 02:23:03.647924: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 02:23:06.139267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorshipyolov8n_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 10339 backgrounds, 0 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [1:04:47<00:00,  3.02it/s]
#                    all      11743      35186      0.594      0.665      0.583      0.258
# Speed: 2.6ms preprocess, 300.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val11

# %%
# !yolo val task=detect model=diorshipyolov8s_full_integer_quant.tflite imgsz=800 data=DIORyolov8test.yaml #new stuff the yamls fine
# Out:
# 2023-04-06 12:07:05.267966: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 12:07:06.879469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.66 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorshipyolov8s_full_integer_quant.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 10339 backgrounds, 0 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [4:14:40<00:00,  1.30s/it]
#                    all      11743      35186      0.585      0.637      0.489       0.22
# Speed: 9.1ms preprocess, 951.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/val3

# %%
# !yolo val model=diorshipyolov8n_float16.tflite data=DIORyolov8test.yaml  imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# 2023-04-07 11:38:55.979022: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 11:38:58.189234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.68 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorshipyolov8n_float16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 10339 backgrounds, 0 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [2:35:19<00:00,  1.26it/s]
#                    all      11743      35186      0.936      0.818      0.896      0.571
# Speed: 2.7ms preprocess, 476.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val3

# %%
# !yolo val model=diorshipyolov8s_float16.tflite data=DIORyolov8test.yaml  imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# 2023-04-07 14:15:35.897520: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 14:15:38.697549: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.68 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorshipyolov8s_float16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 10339 backgrounds, 0 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [5:09:03<00:00,  1.58s/it]
#                    all      11743      35186      0.946      0.842      0.912      0.596
# Speed: 2.6ms preprocess, 1548.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val4

# %%
# !yolo val model=diorallyolov8s_float16.tflite data=DIORyolov8test.yaml  imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# 2023-04-08 14:49:39.974409: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 14:49:42.786908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorallyolov8s_float16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 5 backgrounds, 20 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [5:20:49<00:00,  1.64s/it]
#                    all      11743     124445      0.829      0.638      0.705      0.504
#              golffield      11743        575      0.702       0.73      0.727      0.475
# Expressway-toll-station      11743        688      0.897      0.517      0.613      0.508
#                vehicle      11743      26640      0.831      0.459      0.591      0.352
#           trainstation      11743        509      0.472       0.58      0.482      0.267
#                chimney      11743       1031      0.957      0.741      0.788      0.679
#            storagetank      11743      23361      0.959      0.668      0.836      0.565
#                   ship      11743      35186      0.948      0.861      0.917      0.619
#                 harbor      11743       3105      0.772       0.56      0.619      0.411
#               airplane      11743       8212      0.972      0.733      0.864       0.62
#       groundtrackfield      11743       1885      0.761      0.675      0.744      0.585
#            tenniscourt      11743       7343      0.972      0.819      0.893      0.798
#                    dam      11743        538      0.596      0.551      0.533      0.302
#        basketballcourt      11743       2146      0.933      0.867      0.903        0.8
# Expressway-Service-area      11743       1085        0.9      0.565      0.593      0.437
#                stadium      11743        672      0.797      0.427      0.637      0.453
#                airport      11743        666      0.741      0.676      0.711       0.46
#          baseballfield      11743       3434      0.944      0.667      0.773       0.67
#                 bridge      11743       2589      0.756      0.354      0.449      0.252
#               windmill      11743       2998       0.93      0.758      0.828      0.431
#               overpass      11743       1782      0.743      0.546        0.6       0.39
# Speed: 3.4ms preprocess, 1601.3ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val3

# %%
# !yolo val model=diorallyolov8n_float16.tflite data=DIORyolov8test.yaml  imgsz=800
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify', or 'pose'.
# 2023-04-08 12:04:30.532243: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 12:04:31.955857: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.70 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Loading diorallyolov8n_float16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Forcing batch=1 square inference (1,3,800,800) for non-PyTorch models
# val: Scanning /content/drive/MyDrive/Colab Notebooks/dataset/DIOR/test/labels.cache... 11738 images, 5 backgrounds, 20 corrupt: 100% 11743/11743 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 11743/11743 [2:42:58<00:00,  1.20it/s]
#                    all      11743     124445      0.814      0.608      0.673      0.471
#              golffield      11743        575      0.636      0.715      0.634      0.395
# Expressway-toll-station      11743        688      0.833        0.5      0.553      0.451
#                vehicle      11743      26640      0.869      0.395      0.549      0.321
#           trainstation      11743        509      0.466      0.564      0.502      0.257
#                chimney      11743       1031      0.946      0.726      0.758      0.642
#            storagetank      11743      23361      0.958      0.615      0.788      0.523
#                   ship      11743      35186      0.948      0.838      0.905      0.592
#                 harbor      11743       3105      0.786       0.54      0.624      0.417
#               airplane      11743       8212      0.949      0.714       0.84      0.583
#       groundtrackfield      11743       1885      0.762      0.605      0.699      0.522
#            tenniscourt      11743       7343      0.963      0.824      0.896      0.778
#                    dam      11743        538      0.545       0.55      0.514      0.274
#        basketballcourt      11743       2146      0.924      0.854      0.886      0.769
# Expressway-Service-area      11743       1085      0.886      0.554      0.575      0.418
#                stadium      11743        672      0.801      0.342      0.565      0.404
#                airport      11743        666      0.646      0.637      0.655      0.412
#          baseballfield      11743       3434      0.939      0.661      0.766      0.658
#                 bridge      11743       2589      0.703      0.308       0.39      0.226
#               windmill      11743       2998      0.898      0.716      0.783        0.4
#               overpass      11743       1782      0.814      0.507      0.577      0.376
# Speed: 3.5ms preprocess, 516.0ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val2

# %%
from ultralytics import YOLO

model = YOLO('diorallyolov8n.pt')
model.export(format='edgetpu')
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# Model summary (fused): 168 layers, 3009548 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from diorallyolov8n.pt with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 24, 13125) (6.0 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.12.0...
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: simplifying with onnxsim 0.4.19...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success ✅ 3.2s, saved as diorallyolov8n.onnx (11.7 MB)
#
# TensorFlow SavedModel: running 'onnx2tf -i diorallyolov8n.onnx -o diorallyolov8n_saved_model -nuo --non_verbose -oiqt -qt per-tensor -qcind images diorallyolov8n_saved_model/calib_data.npy "[[[[0, 0, 0]]]]" "[[[[255, 255, 255]]]]"'
# TensorFlow SavedModel: export success ✅ 973.8s, saved as diorallyolov8n_saved_model (39.5 MB)
# Edge TPU: WARNING ⚠️ Edge TPU known bug https://github.com/ultralytics/ultralytics/issues/1185
#
# Edge TPU: starting export with Edge TPU compiler 16.0.384591198...
# Edge TPU: running 'edgetpu_compiler -s -d -k 10 --out_dir diorallyolov8n_saved_model diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant.tflite'
# Edge TPU: export success ✅ 25.8s, saved as diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite (3.4 MB)
#
# Export complete (1000.7s)
# Results saved to /content
# Predict:         yolo predict task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=800
# Validate:        yolo val task=detect model=diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite imgsz=800 data=DIORyolov8.yaml
# Visualize:       https://netron.app
# 'diorallyolov8n_saved_model/diorallyolov8n_full_integer_quant_edgetpu.tflite'

# %% [markdown]
# # 5. Python Usage
#
# YOLOv8 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLOv8 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See a detailed Python usage examples in the YOLOv8 [Docs](https://docs.ultralytics.com/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco128.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
success = model.export(format='onnx')  # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.Detect                [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# Ultralytics YOLOv8.0.58 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9bc1cc202ce9> in <module>
#       6
#       7 # Use the model
# ----> 8 results = model.train(data='coco128.yaml', epochs=3)  # train the model
#       9 results = model.val()  # evaluate model performance on the validation set
#      10 results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     322
#     323         self.task = overrides.get('task') or self.task
# --> 324         self.trainer = TASK_MAP[self.task][1](overrides=overrides)
#     325         if not overrides.get('resume'):  # manually set model only if not resuming
#     326             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/engine/trainer.py in __init__(self, cfg, overrides)
#      87         self.model = None
#      88         self.metrics = None
# ---> 89         init_seeds(self.args.seed + 1 + RANK, deterministic=self.args.deterministic)
#      90
#      91         # Dirs
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/yolo/utils/torch_utils.py in init_seeds(seed, deterministic)
#     267     random.seed(seed)
#     268     np.random.seed(seed)
# --> 269     torch.manual_seed(seed)
#     270     torch.cuda.manual_seed(seed)
#     271     torch.cuda.manual_seed_all(seed)  # for Multi-GPU, exception safe
#
# /usr/local/lib/python3.9/dist-packages/torch/random.py in manual_seed(seed)
#      38
#      39     if not torch.cuda._is_in_bad_fork():
# ---> 40         torch.cuda.manual_seed_all(seed)
#      41
#      42     return default_generator.manual_seed(seed)
#
# /usr/local/lib/python3.9/dist-packages/torch/cuda/random.py in manual_seed_all(seed)
#     111             default_generator.manual_seed(seed)
#     112
# --> 113     _lazy_call(cb, seed_all=True)
#     114
#     115
#
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py in _lazy_call(callable, **kwargs)
#     163 def _lazy_call(callable, **kwargs):
#     164     if is_initialized():
# --> 165         callable()
#     166     else:
#     167         # TODO(torch_deploy): this accesses linecache, which attempts to read the
#
# /usr/local/lib/python3.9/dist-packages/torch/cuda/random.py in cb()
#     109         for i in range(device_count()):
#     110             default_generator = torch.cuda.default_generators[i]
# --> 111             default_generator.manual_seed(seed)
#     112
#     113     _lazy_call(cb, seed_all=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # 6. Tasks
#
# YOLOv8 can train, val, predict and export models for the 3 primary tasks in vision AI: detection, segmentation and classification.
#
# <img width="1024" src="https://user-images.githubusercontent.com/26833433/212094133-6bb8c21c-3d47-41df-a512-81c5931054ae.png">

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detection/) for full details.

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLOv8 _segmentation_ models use the `-seg` suffix, i.e. `yolov8n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segmentation/) for full details.

# %%
# Load YOLOv8n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  # load a pretrained YOLOv8n segmentation model
model.train(data='coco128-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLOv8 _classification_ models use the `-cls` suffix, i.e. `yolov8n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classification/) for full details.

# %%
# Load YOLOv8n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained YOLOv8n classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Git clone install (for development)
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics

# %%
# Run YOLOv8 tests (git clone install only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolov8{x}.pt data=coco.yaml
