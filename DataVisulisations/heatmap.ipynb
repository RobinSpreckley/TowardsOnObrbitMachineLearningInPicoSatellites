# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
    return all_data

def get_avg_highest_real_memory(dataframes, top_n=10):
    highest_values = []
    for df in dataframes:
        highest_values.extend(df['Real (MB)'].nlargest(top_n).tolist())
    return np.mean(highest_values)

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
avg_highest_memory = []

for folder in folders:
    data = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    avg_highest_memory.append(avg)

heatmap_data = np.array(avg_highest_memory).reshape(len(folders), 1)
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', yticklabels=folders, xticklabels=['Avg Highest Real Memory'])
plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2884108320.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
    return all_data

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []

max_files = 0
for folder in folders:
    data = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', yticklabels=folders, xticklabels=list(range(1, max_files + 1)))
plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')
plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\4291226001.py:12: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', yticklabels=folders, fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set xticklabels to filenames
filenames_xticks = []
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(filenames_xticks, rotation=90)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\1820765679.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory).transpose()
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', xticklabels=folders, fmt='.2f')

plt.ylabel('Files')
plt.xlabel('Folders')
plt.title('Avg Highest Real Memory')

# Set yticklabels to filenames
filenames_yticks = []
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Set the number of yticks and the labels
box_height = 1
heatmap.set_yticks(np.arange(heatmap_data.shape[0]) + box_height / 2)
heatmap.set_yticklabels(unique_filenames, rotation=0)

plt.show()
#correct mem for subplot
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\3417716050.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def get_all_avg_highest_memory(folders):
    all_avg_highest_memory = []
    filenames_list = []
    max_files = 0
    
    for folder in folders:
        data, filenames = read_files_in_folder(folder)
        avg = get_avg_highest_real_memory(data)
        max_files = max(max_files, len(avg))
        all_avg_highest_memory.append(avg)
        filenames_list.append(filenames)

    # Fill the missing values with NaN
    for i in range(len(all_avg_highest_memory)):
        if len(all_avg_highest_memory[i]) < max_files:
            all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

    return all_avg_highest_memory, filenames_list

def plot_heatmap(heatmap_data, folders, unique_filenames):
    plt.figure(figsize=(15, 5))  
    heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', xticklabels=folders, fmt='.2f')

    plt.ylabel('Files')
    plt.xlabel('Folders')
    plt.title('Avg Highest Real Memory')

    # Set yticklabels to filenames
    box_height = 1
    heatmap.set_yticks(np.arange(heatmap_data.shape[0]) + box_height / 2)
    heatmap.set_yticklabels(unique_filenames, rotation=0)

    plt.show()

folders = ['memory/n2+CPU/processrecordings/output_directory','memory/n2+CPUGPU/processrecorder/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']

all_avg_highest_memory, filenames_list = get_all_avg_highest_memory(folders)
heatmap_data = np.array(all_avg_highest_memory).transpose()

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

plot_heatmap(heatmap_data, custom_x_labels, custom_y_labels)
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4811: expected 4 fields, saw 9\nSkipping line 9593: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4071: expected 4 fields, saw 9\nSkipping line 8186: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10919: expected 4 fields, saw 9\nSkipping line 21627: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8619: expected 4 fields, saw 9\nSkipping line 17212: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4174: expected 4 fields, saw 9\nSkipping line 8395: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3572: expected 4 fields, saw 9\nSkipping line 7149: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10114: expected 4 fields, saw 9\nSkipping line 20251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7965: expected 4 fields, saw 9\nSkipping line 16147: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5159: expected 4 fields, saw 9\nSkipping line 10362: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4531: expected 4 fields, saw 9\nSkipping line 9056: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5502: expected 4 fields, saw 9\nSkipping line 10973: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3353: expected 4 fields, saw 9\nSkipping line 6685: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9746: expected 4 fields, saw 9\nSkipping line 19545: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6564: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9728: expected 4 fields, saw 9\nSkipping line 19402: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6172: expected 4 fields, saw 9\nSkipping line 12251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def get_all_avg_highest_memory(folders):
    all_avg_highest_memory = []
    filenames_list = []
    max_files = 0
    
    for folder in folders:
        data, filenames = read_files_in_folder(folder)
        avg = get_avg_highest_real_memory(data)
        max_files = max(max_files, len(avg))
        all_avg_highest_memory.append(avg)
        filenames_list.append(filenames)

    # Fill the missing values with NaN
    for i in range(len(all_avg_highest_memory)):
        if len(all_avg_highest_memory[i]) < max_files:
            all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

    return all_avg_highest_memory, filenames_list

def plot_heatmap(heatmap_data, folders, unique_filenames):
    plt.figure(figsize=(15, 5))  
    heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', xticklabels=folders, fmt='.2f')

    plt.ylabel('Files')
    plt.xlabel('Folders')
    plt.title('Avg Highest Real Memory')

    # Set yticklabels to filenames
    box_height = 1
    heatmap.set_yticks(np.arange(heatmap_data.shape[0]) + box_height / 2)
    heatmap.set_yticklabels(unique_filenames, rotation=0)

    plt.show()

folders = ['memory/n2+CPU/processrecordings/output_directory','memory/n2+CPUGPU/processrecorder/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']

all_avg_highest_memory, filenames_list = get_all_avg_highest_memory(folders)
heatmap_data = np.array(all_avg_highest_memory).transpose()

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

plot_heatmap(heatmap_data, custom_x_labels, custom_y_labels)
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4811: expected 4 fields, saw 9\nSkipping line 9593: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4071: expected 4 fields, saw 9\nSkipping line 8186: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10919: expected 4 fields, saw 9\nSkipping line 21627: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8619: expected 4 fields, saw 9\nSkipping line 17212: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4174: expected 4 fields, saw 9\nSkipping line 8395: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3572: expected 4 fields, saw 9\nSkipping line 7149: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10114: expected 4 fields, saw 9\nSkipping line 20251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7965: expected 4 fields, saw 9\nSkipping line 16147: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5159: expected 4 fields, saw 9\nSkipping line 10362: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4531: expected 4 fields, saw 9\nSkipping line 9056: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5502: expected 4 fields, saw 9\nSkipping line 10973: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3353: expected 4 fields, saw 9\nSkipping line 6685: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9746: expected 4 fields, saw 9\nSkipping line 19545: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6564: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9728: expected 4 fields, saw 9\nSkipping line 19402: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6172: expected 4 fields, saw 9\nSkipping line 12251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\449910963.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_median_real_memory(dataframes):
    folder_values = []
    for df in dataframes:
        median_value = df['Real (MB)'].median()
        folder_values.append(median_value)
    return folder_values

def get_all_median_memory(folders):
    all_median_memory = []
    filenames_list = []
    max_files = 0
    
    for folder in folders:
        data, filenames = read_files_in_folder(folder)
        medians = get_median_real_memory(data)
        max_files = max(max_files, len(medians))
        all_median_memory.append(medians)
        filenames_list.append(filenames)

    # Fill the missing values with NaN
    for i in range(len(all_median_memory)):
        if len(all_median_memory[i]) < max_files:
            all_median_memory[i].extend([np.nan] * (max_files - len(all_median_memory[i])))

    return all_median_memory, filenames_list

def plot_heatmap(heatmap_data, folders, unique_filenames):
    plt.figure(figsize=(15, 5))  
    heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', xticklabels=folders, fmt='.2f')

    plt.ylabel('Files')
    plt.xlabel('Folders')
    plt.title('Median Real Memory')

    # Set yticklabels to filenames
    box_height = 1
    heatmap.set_yticks(np.arange(heatmap_data.shape[0]) + box_height / 2)
    heatmap.set_yticklabels(unique_filenames, rotation=0)

    plt.show()

folders = ['memory/n2+CPU/processrecordings/output_directory','memory/n2+CPUGPU/processrecorder/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']

all_median_memory, filenames_list = get_all_median_memory(folders)
heatmap_data_mem_median = np.array(all_median_memory).transpose()

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

plot_heatmap(heatmap_data_mem_median, folders, unique_filenames)
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4811: expected 4 fields, saw 9\nSkipping line 9593: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4071: expected 4 fields, saw 9\nSkipping line 8186: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10919: expected 4 fields, saw 9\nSkipping line 21627: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8619: expected 4 fields, saw 9\nSkipping line 17212: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4174: expected 4 fields, saw 9\nSkipping line 8395: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3572: expected 4 fields, saw 9\nSkipping line 7149: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10114: expected 4 fields, saw 9\nSkipping line 20251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7965: expected 4 fields, saw 9\nSkipping line 16147: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5159: expected 4 fields, saw 9\nSkipping line 10362: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4531: expected 4 fields, saw 9\nSkipping line 9056: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5502: expected 4 fields, saw 9\nSkipping line 10973: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3353: expected 4 fields, saw 9\nSkipping line 6685: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9746: expected 4 fields, saw 9\nSkipping line 19545: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6564: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9728: expected 4 fields, saw 9\nSkipping line 19402: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6172: expected 4 fields, saw 9\nSkipping line 12251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\2420035318.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', yticklabels=folders, fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set xticklabels to filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(unique_filenames, rotation=90)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_21760\450509586.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set xticklabels to filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(unique_filenames, rotation=90)

# Set custom y-axis labels
custom_y_labels = ['Custom Y1', 'Custom Y2', 'Custom Y3', 'Custom Y4']
heatmap.set_yticks(np.arange(len(custom_y_labels)))
heatmap.set_yticklabels(custom_y_labels)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\901884316.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set xticklabels to filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(unique_filenames, rotation=90)

# Set custom y-axis labels
custom_y_labels = ['Custom Y1', 'Custom Y2', 'Custom Y3', 'Custom Y4']
heatmap.set_yticks(np.arange(len(custom_y_labels)) + 0.5)
heatmap.set_yticklabels(custom_y_labels)

# Adjust the size of the boxes
heatmap.set_aspect(1.5)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\1023609633.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set custom x-axis labels
custom_x_labels = ['Custom X1', 'Custom X2', 'Custom X3', 'Custom X4', 'Custom X5', 'Custom X6', 'Custom X7', 'Custom X8', 'Custom X9', 'Custom X10', 'Custom X11', 'Custom X12', 'Custom X13', 'Custom X14', 'Custom X15', 'Custom X16']

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(len(custom_x_labels)) + box_width / 2)
heatmap.set_xticklabels(custom_x_labels, rotation=90)

# Set custom y-axis labels
custom_y_labels = ['Custom Y1', 'Custom Y2', 'Custom Y3', 'Custom Y4']
heatmap.set_yticks(np.arange(len(custom_y_labels)) + 0.5)
heatmap.set_yticklabels(custom_y_labels)

# Adjust the size of the boxes
heatmap.set_aspect(1.5)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_444\2754589727.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def swap_columns(data, index1, index2):
    data[:, [index1, index2]] = data[:, [index2, index1]]

folders = ['memory/n2+CPU/processrecordings/output_directory', 'memory/n2+GPU/n2+pyrecord/output_directory','memory/odroidxu4/processrecordings/output_directory','memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)
plt.figure(figsize=(15, 5))  
heatmap = sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f')

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set xticklabels to filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Swap columns and their corresponding labels
index1 = 10
index2 = 12

# Swap columns in the heatmap_data array
swap_columns(heatmap_data, index1, index2)



# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]

index1 = 11
index2 = 13
swap_columns(heatmap_data, index1, index2)
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]

# Set the number of xticks and the labels
box_width = 1
heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(unique_filenames, rotation=90)

# Set custom y-axis labels
custom_y_labels = ['N2+CPU', 'N2+GPU', 'OdroidXU4', 'RPI3B+']
heatmap.set_yticks(np.arange(len(custom_y_labels)) + 0.5)
heatmap.set_yticklabels(custom_y_labels)

# Adjust the size of the boxes
heatmap.set_aspect(1.5)

plt.show()
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_9020\2493278333.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
            all_data.append(df)
            filenames.append(file)
    return all_data, filenames

def get_median_real_memory(dataframes):
    folder_values = []
    for df in dataframes:
        median_value = df['Real (MB)'].median()
        folder_values.append(median_value)
    return folder_values

def get_avg_highest_real_memory(dataframes, top_n=10):
    folder_values = []
    for df in dataframes:
        highest_values = df['Real (MB)'].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

folders = ['GPU/memory/output_directory','OLD/memory/n2+CPU/processrecordings/output_directory','OLD/memory/n2+CPUGPU/processrecorder/output_directory', 'OLD/memory/n2+GPU/n2+pyrecord/output_directory','OLD/memory/odroidxu4/processrecordings/output_directory','OLD/memory/pi3b+/processrecordings/output_directory']
all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_files_in_folder(folder)
    avg = get_avg_highest_real_memory(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)

# Set xticklabels to filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Convert the heatmap_data array to a DataFrame
heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)



# Swap columns and their corresponding labels
index1 = 10
index2 = 12
index3 = 11
index4 = 13

# Swap columns in the heatmap_df DataFrame
heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

plt.figure(figsize=(15, 3))
custom_y_labels = ['N2+CPU', 'N2+CPUGPU','N2+GPU', 'OdroidXU4', 'RPI3B+']
heatmap = sns.heatmap(heatmap_df, annot=True, cmap='coolwarm', fmt='.0f', yticklabels=custom_y_labels)

plt.xlabel('Files')
plt.ylabel('Folders')
plt.title('Avg Highest Real Memory')

# Set the number of xticks and the labels
box_width = 1


custom_x_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(custom_x_labels, rotation=45)

folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
heatmap_df.index = folder_names


heatmap_df.columns = custom_x_labels
heatmap_df.to_csv('median_memory_heatmap_data.csv')
# Out:
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3979: expected 4 fields, saw 9\nSkipping line 7959: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10839: expected 4 fields, saw 9\nSkipping line 21388: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7706: expected 4 fields, saw 9\nSkipping line 15484: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 28763: expected 4 fields, saw 9\nSkipping line 55412: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3215: expected 4 fields, saw 9\nSkipping line 6445: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10120: expected 4 fields, saw 9\nSkipping line 20228: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7082: expected 4 fields, saw 9\nSkipping line 14076: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 28421: expected 4 fields, saw 9\nSkipping line 54341: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8343: expected 4 fields, saw 9\nSkipping line 16847: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10794: expected 4 fields, saw 9\nSkipping line 21534: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7792: expected 4 fields, saw 9\nSkipping line 15508: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10051: expected 4 fields, saw 9\nSkipping line 20243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10712: expected 4 fields, saw 9\nSkipping line 21713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16974: expected 4 fields, saw 9\nSkipping line 33653: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10581: expected 4 fields, saw 9\nSkipping line 20939: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16152: expected 4 fields, saw 9\nSkipping line 32314: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4729: expected 4 fields, saw 9\nSkipping line 9509: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4047: expected 4 fields, saw 9\nSkipping line 8105: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10772: expected 4 fields, saw 9\nSkipping line 21626: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8669: expected 4 fields, saw 9\nSkipping line 17245: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4206: expected 4 fields, saw 9\nSkipping line 8488: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3568: expected 4 fields, saw 9\nSkipping line 7113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10327: expected 4 fields, saw 9\nSkipping line 20675: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8093: expected 4 fields, saw 9\nSkipping line 16113: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5218: expected 4 fields, saw 9\nSkipping line 10423: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4575: expected 4 fields, saw 9\nSkipping line 9119: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5497: expected 4 fields, saw 9\nSkipping line 11055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3390: expected 4 fields, saw 9\nSkipping line 6778: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9832: expected 4 fields, saw 9\nSkipping line 19713: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6638: expected 4 fields, saw 9\nSkipping line 13302: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9675: expected 4 fields, saw 9\nSkipping line 19619: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6191: expected 4 fields, saw 9\nSkipping line 12403: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4811: expected 4 fields, saw 9\nSkipping line 9593: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4071: expected 4 fields, saw 9\nSkipping line 8186: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10919: expected 4 fields, saw 9\nSkipping line 21627: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8619: expected 4 fields, saw 9\nSkipping line 17212: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4174: expected 4 fields, saw 9\nSkipping line 8395: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3572: expected 4 fields, saw 9\nSkipping line 7149: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10114: expected 4 fields, saw 9\nSkipping line 20251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7965: expected 4 fields, saw 9\nSkipping line 16147: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5159: expected 4 fields, saw 9\nSkipping line 10362: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 4531: expected 4 fields, saw 9\nSkipping line 9056: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5502: expected 4 fields, saw 9\nSkipping line 10973: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3353: expected 4 fields, saw 9\nSkipping line 6685: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9746: expected 4 fields, saw 9\nSkipping line 19545: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6564: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9728: expected 4 fields, saw 9\nSkipping line 19402: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6172: expected 4 fields, saw 9\nSkipping line 12251: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3391: expected 4 fields, saw 9\nSkipping line 6768: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9303: expected 4 fields, saw 9\nSkipping line 18642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6909: expected 4 fields, saw 9\nSkipping line 13723: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23984: expected 4 fields, saw 9\nSkipping line 48152: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 2956: expected 4 fields, saw 9\nSkipping line 5917: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 8747: expected 4 fields, saw 9\nSkipping line 17557: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6707: expected 4 fields, saw 9\nSkipping line 13131: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23586: expected 4 fields, saw 9\nSkipping line 46758: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3544: expected 4 fields, saw 9\nSkipping line 7055: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6164: expected 4 fields, saw 9\nSkipping line 12042: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 3449: expected 4 fields, saw 9\nSkipping line 6877: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5682: expected 4 fields, saw 9\nSkipping line 11326: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6202: expected 4 fields, saw 9\nSkipping line 12501: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11935: expected 4 fields, saw 9\nSkipping line 23954: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6175: expected 4 fields, saw 9\nSkipping line 12243: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11615: expected 4 fields, saw 9\nSkipping line 23099: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 14185: expected 4 fields, saw 9\nSkipping line 28613: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10729: expected 4 fields, saw 9\nSkipping line 21143: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29840: expected 4 fields, saw 9\nSkipping line 59865: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 19382: expected 4 fields, saw 9\nSkipping line 38642: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12976: expected 4 fields, saw 9\nSkipping line 26026: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9334: expected 4 fields, saw 9\nSkipping line 18709: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 29005: expected 4 fields, saw 9\nSkipping line 57718: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 18135: expected 4 fields, saw 9\nSkipping line 36170: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13436: expected 4 fields, saw 9\nSkipping line 26728: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10414: expected 4 fields, saw 9\nSkipping line 20658: expected 4 fields, saw 9\nSkipping line 30873: expected 4 fields, saw 9\nSkipping line 31885: expected 4 fields, saw 9\nSkipping line 32927: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13046: expected 4 fields, saw 9\nSkipping line 26016: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9774: expected 4 fields, saw 9\nSkipping line 19480: expected 4 fields, saw 9\nSkipping line 29187: expected 4 fields, saw 9\nSkipping line 30960: expected 4 fields, saw 9\nSkipping line 32555: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 24036: expected 4 fields, saw 9\nSkipping line 47793: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 16243: expected 4 fields, saw 9\nSkipping line 32538: expected 4 fields, saw 9\nSkipping line 48862: expected 4 fields, saw 9\nSkipping line 60407: expected 4 fields, saw 9\nSkipping line 71932: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 23491: expected 4 fields, saw 9\nSkipping line 47217: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 15769: expected 4 fields, saw 9\nSkipping line 31709: expected 4 fields, saw 9\nSkipping line 47562: expected 4 fields, saw 9\nSkipping line 57832: expected 4 fields, saw 9\nSkipping line 68278: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7878: expected 4 fields, saw 9\nSkipping line 15659: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6791: expected 4 fields, saw 9\nSkipping line 13643: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 13729: expected 4 fields, saw 9\nSkipping line 27373: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11391: expected 4 fields, saw 9\nSkipping line 22885: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6673: expected 4 fields, saw 9\nSkipping line 13313: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5753: expected 4 fields, saw 9\nSkipping line 11542: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 12951: expected 4 fields, saw 9\nSkipping line 25913: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10299: expected 4 fields, saw 9\nSkipping line 20566: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7841: expected 4 fields, saw 9\nSkipping line 15636: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7241: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 7507: expected 4 fields, saw 9\nSkipping line 14968: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6839: expected 4 fields, saw 9\nSkipping line 13684: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11886: expected 4 fields, saw 9\nSkipping line 24002: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10249: expected 4 fields, saw 9\nSkipping line 20628: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 11474: expected 4 fields, saw 9\nSkipping line 23011: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 10072: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 6078: expected 4 fields, saw 9\nSkipping line 12070: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 5398: expected 4 fields, saw 9\nSkipping line 10763: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9842: expected 4 fields, saw 9\nSkipping line 19597: expected 4 fields, saw 9\n'
# C:\Users\jspre\AppData\Local\Temp\ipykernel_12792\3737213707.py:13: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(filepath, skiprows=1, delimiter=r'\s+', names=['Elapsed time', 'CPU (%)', 'Real (MB)', 'Virtual (MB)'], error_bad_lines=False)
# b'Skipping line 9098: expected 4 fields, saw 9\nSkipping line 18142: expected 4 fields, saw 9\n'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 13 in <cell line: 95>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X15sZmlsZQ%3D%3D?line=91'>92</a> heatmap.set_xticklabels(custom_x_labels, rotation=45)
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X15sZmlsZQ%3D%3D?line=93'>94</a> folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X15sZmlsZQ%3D%3D?line=94'>95</a> heatmap_df.index = folder_names
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X15sZmlsZQ%3D%3D?line=97'>98</a> heatmap_df.columns = custom_x_labels
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X15sZmlsZQ%3D%3D?line=98'>99</a> heatmap_df.to_csv('median_memory_heatmap_data.csv')
#
# File c:\Users\jspre\anaconda3\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File c:\Users\jspre\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\jspre\anaconda3\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File c:\Users\jspre\anaconda3\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File c:\Users\jspre\anaconda3\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 5 elements

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def calculate_eighth_value_average(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    eighth_values = []
    
    for line in lines:
        if not line.strip():  # Ignore empty lines
            continue
        
        values = line.split(',')
        if len(values) == 15:  # Only process lines with 15 values
            eighth_value = float(values[12])  # Get the 8th value (0-indexed)
            eighth_values.append(eighth_value)

    average = sum(eighth_values) / len(eighth_values)
    return average

# Usage
filename = 'odroidxu4.txt'
average = calculate_eighth_value_average(filename)
print("Average of the 8th values:", average)




def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' not in file or 'start' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames



def get_avg_highest_new_data(folder_name, dataframes, top_n=10):
    column = folder_column_index[folder_name]  # Get the desired column index based on the folder name
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        print(highest_values)
        # Subtract the average standby power for the folder
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        print(adjusted_values)
        folder_values.append(np.mean(adjusted_values))
    return folder_values

def get_avg_new_data(folder_name, dataframes):
    column = folder_column_index[folder_name]  # Get the desired column index based on the folder name
    folder_values = []
    for df in dataframes:
        average_value = df[column].mean()  # Calculate the mean
        adjusted_value = average_value - avg_standby_power[folder_name]  # Subtract the average standby power for the folder
        folder_values.append(adjusted_value)
    return folder_values

def get_median_new_data(folder_name, dataframes):
    column = folder_column_index[folder_name]  # Get the desired column index based on the folder name
    folder_values = []
    for df in dataframes:
        median_value = df[column].median()  # Calculate the median
        adjusted_value = median_value - avg_standby_power[folder_name]  # Subtract the average standby power for the folder
        folder_values.append(adjusted_value)
    return folder_values

avg_standby_power = {
    'n2+cpupower': 2244.686,
    'cputhenGPU':2244.686,
    'fullgpu': 2244.686,
    'odroidxu4power': 2877.658,
    'pi3b+cpupower': 2244.667,
}
"""
avg_standby_power = {
    'n2+cpupower': 0,
    'cputhenGPU':0,
    'fullgpu': 0,
    'odroidxu4power': 0,
    'pi3b+cpupower': 0,
}
"""
folder_column_index = {
    'n2+cpupower':12,
    'cputhenGPU':12,
    'fullgpu':12,
    'odroidxu4power':12,
    'pi3b+cpupower': 7,
}


# Replace the folders variable with the new set of folders
folders = ['n2+cpupower', 'cputhenGPU','fullgpu', 'odroidxu4power', 'pi3b+cpupower']

# Update the loop that processes the folders
all_avg_highest_memory = []
filenames_list = []

max_files = 36
for folder in folders:
    data, filenames = read_new_files_in_folder(folder)
    avg = get_avg_new_data(folder, data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

# Fill the missing values with NaN
for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)

# Get unique filenames
unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Convert the heatmap_data array to a DataFrame
heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
# Swap columns and their corresponding labels
'''
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]
'''
# Swap columns in the heatmap_df DataFrame

# Set xticklabels to filenames
custom_y_labels = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']


plt.figure(figsize=(30, 3))
heatmap = sns.heatmap(heatmap_df, annot=True, cmap='coolwarm', fmt='.0f', yticklabels=custom_y_labels)


plt.title('Top 10 Avg Highest Power(mW)')

# Set the number of xticks and the labels
box_width = 1

# Replace with your own custom_x_labels
custom_x_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU''test']



heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(custom_x_labels, rotation=90)





folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
heatmap_df.index = folder_names

extension = "_avg"

# Add the extension word to each string in the list
custom_x_labels = [string + extension for string in custom_x_labels]

heatmap_df.columns = custom_x_labels
heatmap_df.to_csv('avgtop10_power_heatmap_data.csv')
plt.show()
# Out:
# Average of the 8th values: 2877.658
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 14 in <cell line: 176>()
#     <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X16sZmlsZQ%3D%3D?line=170'>171</a> custom_x_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU''test']
#     <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X16sZmlsZQ%3D%3D?line=174'>175</a> heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
# --> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X16sZmlsZQ%3D%3D?line=175'>176</a> heatmap.set_xticklabels(custom_x_labels, rotation=90)
#     <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X16sZmlsZQ%3D%3D?line=181'>182</a> folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
#     <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X16sZmlsZQ%3D%3D?line=182'>183</a> heatmap_df.index = folder_names
#
# File c:\Users\jspre\anaconda3\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File c:\Users\jspre\anaconda3\lib\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File c:\Users\jspre\anaconda3\lib\site-packages\matplotlib\axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716 if isinstance(locator, mticker.FixedLocator):
#    1717     # Passing [] as a list of ticklabels is often used as a way to
#    1718     # remove all tick labels, so only error for > 0 ticklabels
#    1719     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720         raise ValueError(
#    1721             "The number of FixedLocator locations"
#    1722             f" ({len(locator.locs)}), usually from a call to"
#    1723             " set_ticks, does not match"
#    1724             f" the number of ticklabels ({len(ticklabels)}).")
#    1725     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1726     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (36), usually from a call to set_ticks, does not match the number of ticklabels (20).

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_new_data(folder_name, dataframes, top_n=10):
    column = folder_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values

def get_avg_new_data(folder_name, dataframes):
    column = folder_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        average_value = df[column].mean()
        adjusted_value = average_value - avg_standby_power[folder_name]
        folder_values.append(adjusted_value)
    return folder_values

def get_median_new_data(folder_name, dataframes):
    column = folder_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        median_value = df[column].median()
        adjusted_value = median_value - avg_standby_power[folder_name]
        folder_values.append(adjusted_value)
    return folder_values

avg_standby_power = {
    'n2+cpupower': 2244.686,
    'cputhenGPU':2244.686,
    'fullgpu': 2244.686,
    'odroidxu4power': 2877.658,
    'pi3b+cpupower': 2244.667,
}

folder_column_index = {
    'n2+cpupower':12,
    'cputhenGPU':12,
    'fullgpu':12,
    'odroidxu4power':12,
    'pi3b+cpupower': 7,
}

folders = ['n2+cpupower', 'cputhenGPU','fullgpu', 'odroidxu4power', 'pi3b+cpupower']

all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_new_files_in_folder(folder)
    avg = get_avg_highest_new_data(folder, data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

# Create a heatmap
def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label):
    plt.figure(figsize=(15, 6))
    ax = sns.heatmap(data, annot=True, cmap="coolwarm", cbar_kws={'label': cbar_label},fmt='.0f')
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(yticklabels, rotation=0)
    plt.show()


custom_y_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

# Swap the corresponding x-labels in the unique_filenames li



# Transpose heatmap_data
heatmap_df = heatmap_df.T

# Get unique folder names
unique_folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

# Plot the heatmaps
create_heatmap(heatmap_df, "Top 10 Avg Highest Power(mW)", "File", "Folder", unique_folder_names, custom_y_labels, "Power(mW)")

# Save the heatmap data to a CSV file
heatmap_df.to_csv('avgtop10_power_heatmap_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 15 in <cell line: 76>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=74'>75</a> max_files = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=75'>76</a> for folder in folders:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=76'>77</a>     data, filenames = read_new_files_in_folder(folder)
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=77'>78</a>     avg = get_avg_highest_new_data(folder, data)
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=78'>79</a>     max_files = max(max_files, len(avg))
#
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 15 in read_new_files_in_folder(folder_path)
#       <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> all_data = []
#       <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> filenames = []
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> for file in os.listdir(folder_path):
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a>     if file.endswith('.txt') and 'infer' in file:
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a>         filepath = os.path.join(folder_path, file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'n2+cpupower'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'start' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values
def get_median_new_data(folder_name, dataframes):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        median_value = df[column].median()
        adjusted_value = median_value - avg_standby_power[folder_name]
        folder_values.append(adjusted_value)
    return folder_values
def get_avg_new_data(folder_name, dataframes):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        average_value = df[column].mean()
        adjusted_value = average_value - avg_standby_power[folder_name]
        folder_values.append(adjusted_value)
    return folder_values


avg_standby_power = {
    'OLD/n2+cpupower': 2244.686,
    'OLD/cputhenGPU':2244.686,
    'OLD/fullgpu': 2244.686,
    'OLD/odroidxu4power': 2877.658,
    'OLD/pi3b+cpupower': 2244.667,
    'GPUallPower': 2244.686,
    'CPUn2+power': 2244.686
}

folder_power_column_index = {
    'OLD/n2+cpupower':12,
    'OLD/cputhenGPU':12,
    'OLD/fullgpu':12,
    'OLD/odroidxu4power':12,
    'OLD/pi3b+cpupower': 7,
    'GPUallPower':12,
    'CPUn2+power': 12
}

folders = ['CPUn2+power','GPUallPower','OLD/n2+cpupower','OLD/fullgpu', 'OLD/odroidxu4power', 'OLD/pi3b+cpupower']

all_avg_highest_power = []
file_names_list = []

max_files = 20
for folder in folders:
    data, filenames = read_inference_files_in_folder(folder)
    avg = get_avg_new_data(folder, data)
    max_files = max(max_files, len(avg))
    all_avg_highest_power.append(avg)
    file_names_list.append(filenames)

for i in range(len(all_avg_highest_power)):
    if len(all_avg_highest_power[i]) < max_files:
        all_avg_highest_power[i].extend([np.nan] * (max_files - len(all_avg_highest_power[i])))

heatmap_data = np.array(all_avg_highest_power)

unique_filenames = []
for filenames in file_names_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label):
    plt.figure(figsize=(15, 6))
    ax = sns.heatmap(data, annot=True, cmap="coolwarm", cbar_kws={'label': cbar_label},fmt='.0f')
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(custom_y_labels, rotation=0)
    plt.show()

custom_y_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

heatmap_df = heatmap_df.T

unique_folder_names = ['N2+ Only CPU','N2+ Only CPU', 'N2+ Mainly CPU', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

create_heatmap(heatmap_df, "Top 10 Avg Highest Power(mW)", "File", "Folder", unique_folder_names, custom_y_labels, "Power(mW)")

heatmap_df.to_csv('avgtop10_power_heatmap_data.csv')

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values
def get_median_new_data(folder_name, dataframes):
    column = folder_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        median_value = df[column].median()
        adjusted_value = median_value - avg_standby_power[folder_name]
        folder_values.append(adjusted_value)
    return folder_values


avg_standby_power = {
    'n2+cpupower': 2244.686,
    'cputhenGPU':2244.686,
    'fullgpu': 2244.686,
    'odroidxu4power': 2877.658,
    'pi3b+cpupower': 2244.667,
}

folder_power_column_index = {
    'n2+cpupower':12,
    'cputhenGPU':12,
    'fullgpu':12,
    'odroidxu4power':12,
    'pi3b+cpupower': 7,
}

folders = ['GPU-NMS','OLD/n2+cpupower', 'OLD/cputhenGPU','OLD/fullgpu', 'OLD/odroidxu4power', 'OLD/pi3b+cpupower']

all_avg_highest_power = []
file_names_list = []

max_files = 0
for folder in folders:
    data, filenames = read_inference_files_in_folder(folder)
    avg = get_median_new_data(folder, data)
    max_files = max(max_files, len(avg))
    all_avg_highest_power.append(avg)
    file_names_list.append(filenames)

for i in range(len(all_avg_highest_power)):
    if len(all_avg_highest_power[i]) < max_files:
        all_avg_highest_power[i].extend([np.nan] * (max_files - len(all_avg_highest_power[i])))

heatmap_data = np.array(all_avg_highest_power)

unique_filenames = []
for filenames in file_names_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label):
    plt.figure(figsize=(15, 6))
    ax = sns.heatmap(data, annot=True, cmap="coolwarm", cbar_kws={'label': cbar_label})
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(yticklabels, rotation=0)
    plt.show()

custom_y_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap_median_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_median_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_median_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_median_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_median_df[[unique_filenames[index4], unique_filenames[index3]]]

unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

heatmap_median_df = heatmap_median_df.T

unique_folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

create_heatmap(heatmap_median_df, "Top 10 Avg Highest Power(mW)", "File", "Folder", unique_folder_names, custom_y_labels, "Power(mW)")

heatmap_median_df.to_csv('avgtop10_power_heatmap_data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 17 in <cell line: 67>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=66'>67</a> for folder in folders:
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=67'>68</a>     data, filenames = read_inference_files_in_folder(folder)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=68'>69</a>     avg = get_median_new_data(folder, data)
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=69'>70</a>     max_files = max(max_files, len(avg))
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=70'>71</a>     all_avg_highest_power.append(avg)
#
# c:\Users\jspre\year5project\HCI\heatmap.ipynb Cell 17 in get_median_new_data(folder_name, dataframes)
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=34'>35</a> def get_median_new_data(folder_name, dataframes):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=35'>36</a>     column = folder_column_index[folder_name]
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=36'>37</a>     folder_values = []
#      <a href='vscode-notebook-cell:/c%3A/Users/jspre/year5project/HCI/heatmap.ipynb#X22sZmlsZQ%3D%3D?line=37'>38</a>     for df in dataframes:
#
# KeyError: 'GPU-NMS'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values

avg_standby_power = {
    'n2+cpupower': 2244.686,
    'cputhenGPU':2244.686,
    'fullgpu': 2244.686,
    'odroidxu4power': 2877.658,
    'pi3b+cpupower': 2244.667,
}

folder_power_column_index = {
    'n2+cpupower':12,
    'cputhenGPU':12,
    'fullgpu':12,
    'odroidxu4power':12,
    'pi3b+cpupower': 7,
}

folders = ['n2+cpupower', 'cputhenGPU','fullgpu', 'odroidxu4power', 'pi3b+cpupower']

all_avg_highest_power = []
file_names_list = []

max_files = 0
for folder in folders:
    data, filenames = read_inference_files_in_folder(folder)
    avg = get_avg_highest_power(folder, data)
    max_files = max(max_files, len(avg))
    all_avg_highest_power.append(avg)
    file_names_list.append(filenames)

for i in range(len(all_avg_highest_power)):
    if len(all_avg_highest_power[i]) < max_files:
        all_avg_highest_power[i].extend([np.nan] * (max_files - len(all_avg_highest_power[i])))

heatmap_data = np.array(all_avg_highest_power)

unique_filenames = []
for filenames in file_names_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label):
    plt.figure(figsize=(15, 6))
    ax = sns.heatmap(data, annot=True, cmap="coolwarm", cbar_kws={'label': cbar_label})
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(yticklabels, rotation=0)
    plt.show()

custom_y_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

heatmap_df = heatmap_df.T

unique_folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

create_heatmap(heatmap_df, "Top 10 Avg Highest Power(mW)", "File", "Folder", unique_folder_names, custom_y_labels, "Power(mW)")

heatmap_df.to_csv('avgtop10_power_heatmap_data.csv')

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values


folders = ['time/n2+cputime/logtime','time/n2+cputhengpu/logfiletime', 'time/n2+gputime/logtime', 'time/odroidxu4time/logfiletime', 'time/pi3b+time/logfiletime']

all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_new_files_in_folder(folder)
    avg = get_median_new_data(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]

custom_y_labels = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

plt.figure(figsize=(10, 4))
heatmap = sns.heatmap(heatmap_df, annot=True, cmap='coolwarm', fmt='.2f', yticklabels=custom_y_labels)


plt.title('Median CPU Time Inference (Seconds)')

box_width = 1

custom_x_labels = unique_filenames  # Use filenames as x labels

custom_x_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']

heatmap.set_xticks(np.arange(heatmap_data.shape[1]) + box_width / 2)
heatmap.set_xticklabels(custom_x_labels, rotation=90)
plt.savefig('median_CPUTIME_heatmap.jpeg', format='jpeg', dpi=1000)
plt.show()

folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
heatmap_df.index = folder_names

extension = "_walltime"

# Add the extension word to each string in the list
custom_x_labels = [string + extension for string in custom_x_labels]


heatmap_df.columns = custom_x_labels
heatmap_df.to_csv('median_CPUTIME_heatmap_data.csv')

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values


folders = ['time/n2+cputime/logtime','time/n2+cputhengpu/logfiletime', 'time/n2+gputime/logtime', 'time/odroidxu4time/logfiletime', 'time/pi3b+time/logfiletime']

all_avg_highest_memory = []
filenames_list = []

max_files = 0
for folder in folders:
    data, filenames = read_new_files_in_folder(folder)
    avg = get_median_new_data(data)
    max_files = max(max_files, len(avg))
    all_avg_highest_memory.append(avg)
    filenames_list.append(filenames)

for i in range(len(all_avg_highest_memory)):
    if len(all_avg_highest_memory[i]) < max_files:
        all_avg_highest_memory[i].extend([np.nan] * (max_files - len(all_avg_highest_memory[i])))

heatmap_data = np.array(all_avg_highest_memory)

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)

heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames)
index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]



heatmap_df = pd.DataFrame(heatmap_data, columns=unique_filenames).T

custom_y_labels = unique_filenames
custom_x_labels = ['N2+ Only CPU', 'N2+ Mainly CPU ', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

plt.figure(figsize=(3, 6))
heatmap = sns.heatmap(heatmap_df, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=custom_x_labels, yticklabels=custom_y_labels)

plt.title('Top 10 CPU Time Inference (Seconds)')

box_width = 1

heatmap.set_yticks(np.arange(heatmap_data.T.shape[0]) + box_width / 2)
heatmap.set_yticklabels(custom_y_labels, rotation=0)
heatmap.set_xticklabels(custom_x_labels)

folder_names = ['N2+ Only CPU', 'N2+ Mainly CPU ', 'N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']
heatmap_df.columns = folder_names

extension = "_walltime"

# Add the extension word to each string in the list
custom_y_labels = [string + extension for string in custom_y_labels]

heatmap_df.index = custom_y_labels
heatmap_df.to_csv('median_CPUTIME_heatmap_data_90.csv')

plt.savefig("Top10CPUtime_rotated.jpeg", dpi=300, bbox_inches='tight', format='jpeg')
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colorbar as cbar

def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values


folders = ['time/n2+cputime/logtime','time/n2+cputhengpu/logfiletime', 'time/n2+gputime/logtime', 'time/odroidxu4time/logfiletime', 'time/pi3b+time/logfiletime']
custom_x_labels = ['N2+ Only CPU', 'N2+ Mainly CPU ','N2+ Mainly GPU', 'Odroidxu4', 'PI3B+']

all_avg_highest_memory_cpu = []
all_avg_highest_memory_wall = []
filenames_list = []

max_files = 0
all_medians_memory_cpu = []
all_medians_memory_wall = []

box_width =1 

for folder in folders:
    data, filenames = read_new_files_in_folder(folder)
    medians_cpu = get_median_new_data(data, time_type='CPUTime')
    avg_highest_cpu = get_avg_highest_new_data(data, time_type='CPUTime')
    medians_wall = get_median_new_data(data, time_type='WallClockTime')
    avg_highest_wall = get_avg_highest_new_data(data, time_type='WallClockTime')
    max_files = max(max_files, len(medians_cpu), len(medians_wall))
    all_avg_highest_memory_cpu.append(avg_highest_cpu)
    all_avg_highest_memory_wall.append(avg_highest_wall)
    all_medians_memory_cpu.append(medians_cpu)
    all_medians_memory_wall.append(medians_wall)
    filenames_list.append(filenames)

unique_filenames = []
for filenames in filenames_list:
    for filename in filenames:
        if filename not in unique_filenames:
            unique_filenames.append(filename)


# Process the data
for i in range(len(all_avg_highest_memory_cpu)):
    if len(all_avg_highest_memory_cpu[i]) < max_files:
        all_avg_highest_memory_cpu[i].extend([np.nan] * (max_files - len(all_avg_highest_memory_cpu[i])))
    if len(all_medians_memory_cpu[i]) < max_files:
        all_medians_memory_cpu[i].extend([np.nan] * (max_files - len(all_medians_memory_cpu[i])))
    if len(all_avg_highest_memory_wall[i]) < max_files:
        all_avg_highest_memory_wall[i].extend([np.nan] * (max_files - len(all_avg_highest_memory_wall[i])))
    if len(all_medians_memory_wall[i]) < max_files:
        all_medians_memory_wall[i].extend([np.nan] * (max_files - len(all_medians_memory_wall[i])))

heatmap_data_avg_cpu = np.array(all_avg_highest_memory_cpu)
heatmap_data_medians_cpu = np.array(all_medians_memory_cpu)

heatmap_data_avg_wall = np.array(all_avg_highest_memory_wall)
heatmap_data_medians_wall = np.array(all_medians_memory_wall)

heatmap_df_medians_cpu = pd.DataFrame(heatmap_data_avg_cpu, columns=unique_filenames)
heatmap_df_medians_wall = pd.DataFrame(heatmap_data_medians_wall, columns=unique_filenames)
heatmap_df_data_avg_cpu = pd.DataFrame(heatmap_data_avg_cpu, columns=unique_filenames)
heatmap__df_data_avg_wall = pd.DataFrame(heatmap_data_avg_wall, columns=unique_filenames)

index1 = 10
index2 = 12
index3 = 11
index4 = 13

heatmap_df_medians_cpu[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df_medians_cpu[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df_medians_cpu[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df_medians_cpu[[unique_filenames[index4], unique_filenames[index3]]]

heatmap_df_medians_wall[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df_medians_wall[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df_medians_wall[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df_medians_wall[[unique_filenames[index4], unique_filenames[index3]]]

heatmap_df_data_avg_cpu[[unique_filenames[index1], unique_filenames[index2]]] = heatmap_df_data_avg_cpu[[unique_filenames[index2], unique_filenames[index1]]]
heatmap_df_data_avg_cpu[[unique_filenames[index3], unique_filenames[index4]]] = heatmap_df_data_avg_cpu[[unique_filenames[index4], unique_filenames[index3]]]

heatmap__df_data_avg_wall[[unique_filenames[index1], unique_filenames[index2]]] = heatmap__df_data_avg_wall[[unique_filenames[index2], unique_filenames[index1]]]
heatmap__df_data_avg_wall[[unique_filenames[index3], unique_filenames[index4]]] = heatmap__df_data_avg_wall[[unique_filenames[index4], unique_filenames[index3]]]

# Swap the corresponding x-labels in the unique_filenames list
unique_filenames[index1], unique_filenames[index2] = unique_filenames[index2], unique_filenames[index1]
unique_filenames[index3], unique_filenames[index4] = unique_filenames[index4], unique_filenames[index3]


heatmap__df_data_avg_wall = heatmap__df_data_avg_wall.T
# Transpose the DataFrames


heatmap_df_data_avg_cpu = heatmap_df_data_avg_cpu.T

heatmap_df_medians_cpu = heatmap_df_medians_cpu.T
# Transpose the DataFrames


heatmap_df_medians_wall = heatmap_df_medians_wall.T
custom_y_labels = ['ALL-8n-FP16', 'ALL-8n-INT8', 'ALL-8s-FP16', 'ALL-8s-INT8', 'SHIP-8n-FP16', 'SHIP-8n-INT8', 'SHIP-8s-FP16', 'SHIP-8s-INT8','ALL-5n-FP16', 'ALL-5n-INT8', 'ALL-5s-FP16', 'ALL-5s-INT8', 'SHIP-5n-FP16', 'SHIP-5n-INT8', 'SHIP-5s-FP16', 'SHIP-5s-INT8','ALL-5n-TPU','SHIP-5n-TPU','ALL-5s-TPU','SHIP-5s-TPU']


fig, axs = plt.subplots(1, 2, figsize=(7, 4), sharey=True)

# First subplot for CPUTime get_median_new_data
sns.heatmap(heatmap_df_medians_cpu, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=custom_x_labels, yticklabels=custom_y_labels, ax=axs[0], cbar=False)
axs[0].set_title('Median CPUTime Inference')
axs[0].set_yticklabels(custom_y_labels, rotation=0)

# Second subplot for WallClockTime get_median_new_data
sns.heatmap(heatmap_df_medians_wall, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=custom_x_labels, yticklabels=custom_y_labels, ax=axs[1], cbar=False)
axs[1].set_title('Median WallClock Time Inference')
axs[1].set_yticklabels(custom_y_labels, rotation=0)

# Set the x-axis labels
axs[0].set_xticklabels(custom_x_labels)
axs[1].set_xticklabels(custom_x_labels)


plt.subplots_adjust(wspace=0.05,hspace=0.1)


# Save the figure
plt.savefig("Subplots_Heatmaps_time.pdf", dpi=300, bbox_inches='tight', format='pdf')
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colorbar as cbar

# Read new files in folder
def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

# Get average highest new data
def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

# Get average new data
def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

# Get median new data
def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values

# Read inference files in folder
def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

# Get average highest power
def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values

# Create heatmap
def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label):
    plt.figure(figsize=(15, 6))
    ax = sns.heatmap(data, annot=True, cmap="coolwarm", c
# Out:
# 'c:\\Users\\jspre\\year5project\\HCI'

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colorbar as cbar

# Read new files in folder
def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

# Get average highest new data
def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

# Get average new data
def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

# Get median new data
def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values

# Read inference files in folder
def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

# Get average highest power
def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values

# Create heatmap
def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label, ax, fmt=".2f", fontsize=10):
    sns.heatmap(data, annot=True, cmap="coolwarm", ax=ax, fmt=fmt, annot_kws={'fontsize': fontsize},cbar=False)
    ax.set_title(title)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(yticklabels, rotation=0)

fig, axs = plt.subplots(1, 4, figsize=(14, 4), sharey=True)

create_heatmap(heatmap_df, "Top 10 Avg Highest Power(mW)", "File", "Folder", custom_x_labels, custom_y_labels, "Power(mW)", axs[2], fmt=".0f", fontsize=8)
create_heatmap(heatmap_data, "Top 10 Avg memory(mW)", "File", "Folder", custom_x_labels, custom_y_labels, "Power(mW)", axs[3], fmt=".2f", fontsize=8)

create_heatmap(heatmap_df_data_avg_cpu, "avg top CPUTime Inference", "File", "Folder", custom_x_labels, custom_y_labels, "CPUTime", axs[0], fmt=".2f", fontsize=8)
create_heatmap(heatmap__df_data_avg_wall, "avg top WallClock Time Inference", "File", "Folder", custom_x_labels, custom_y_labels, "WallClockTime", axs[1], fmt=".2f", fontsize=8)




plt.subplots_adjust(wspace=0.05, hspace=0.1)
# Generate average power heatmap data from power_usage_data


# Convert the power heatmap data to a DataFrame

# Save the power heatmap data to a CSV file
plt.savefig("Combined_Heatmaps_top10avg.pdf", dpi=300, bbox_inches='tight', format='pdf')
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colorbar as cbar

# Read new files in folder
def read_new_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(' ')
                    if len(values) == 3:
                        try:
                            data.append([values[0], float(values[1]), float(values[2])])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data, columns=['Type', 'CPUTime', 'WallClockTime']))
                filenames.append(file)
    return all_data, filenames

# Get average highest new data
def get_avg_highest_new_data(dataframes, data_type='inference', time_type='CPUTime', top_n=10):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        highest_values = filtered_df[time_type].nlargest(top_n).tolist()
        folder_values.append(np.mean(highest_values))
    return folder_values

# Get average new data
def get_avg_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        avg_value = filtered_df[time_type].mean()
        folder_values.append(avg_value)
    return folder_values

# Get median new data
def get_median_new_data(dataframes, data_type='inference', time_type='CPUTime'):
    folder_values = []
    for df in dataframes:
        filtered_df = df[df['Type'] == data_type]
        median_value = filtered_df[time_type].median()
        folder_values.append(median_value)
    return folder_values

# Read inference files in folder
def read_inference_files_in_folder(folder_path):
    all_data = []
    filenames = []
    for file in os.listdir(folder_path):
        if file.endswith('.txt') and 'infer' in file:
            filepath = os.path.join(folder_path, file)
            with open(filepath, 'r') as f:
                lines = f.readlines()
                data = []
                for line in lines:
                    values = line.strip().split(',')
                    if len(values) == 15:
                        try:
                            data.append([float(x) for x in values if x != ''])
                        except ValueError:
                            continue
                all_data.append(pd.DataFrame(data))
                filenames.append(file)
    return all_data, filenames

# Get average highest power
def get_avg_highest_power(folder_name, dataframes, top_n=10):
    column = folder_power_column_index[folder_name]
    folder_values = []
    for df in dataframes:
        highest_values = df[column].nlargest(top_n).tolist()
        adjusted_values = [value - avg_standby_power[folder_name] for value in highest_values]
        folder_values.append(np.mean(adjusted_values))
    return folder_values

# Create heatmap
def create_heatmap(data, title, ylabel, xlabel, xticklabels, yticklabels, cbar_label, ax, fmt=".2f", fontsize=10):
    sns.heatmap(data, annot=True, cmap="coolwarm", ax=ax, fmt=fmt, annot_kws={'fontsize': fontsize},cbar=False)
    ax.set_title(title)
    ax.set_xticklabels(xticklabels, rotation=45)
    ax.set_yticklabels(yticklabels, rotation=0)

fig, axs = plt.subplots(1, 4, figsize=(14, 4), sharey=True)
create_heatmap(heatmap_df_medians_cpu, "Median CPUTime Inference", "File", "Folder", custom_x_labels, custom_y_labels, "CPUTime", axs[0], fmt=".2f", fontsize=8)
create_heatmap(heatmap_df_medians_wall, "Median WallClock Time Inference", "File", "Folder", custom_x_labels, custom_y_labels, "WallClockTime", axs[1], fmt=".2f", fontsize=8)
create_heatmap(heatmap_median_df, "Mdian Power(mW)", "File", "Folder", custom_x_labels, custom_y_labels, "Power(mW)", axs[2], fmt=".0f", fontsize=8)
create_heatmap(heatmap_data_mem_median, "Median memory(MB)", "File", "Folder", custom_x_labels, custom_y_labels, "Power(mW)", axs[3], fmt=".2f", fontsize=8)




plt.subplots_adjust(wspace=0.05, hspace=0.1)
# Generate average power heatmap data from power_usage_data


# Convert the power heatmap data to a DataFrame

# Save the power heatmap data to a CSV file
plt.savefig("Combined_Heatmaps_median.pdf", dpi=300, bbox_inches='tight', format='pdf')
plt.show()
